# %% [markdown]
# ### Barack Obama - Sentiment Analysis

# %% [markdown]
# #### Language Processing Pipeline (Potential Idea - sentence tokenizer, POS, NER using spacy pipeline)

# %% [markdown]
# A pipeline is something that comes after the tokenizer, and can have a number of steps.

# %%
import pandas as pd

# %%
BO_Nov2006 = pd.read_pickle('Obama Speeches Raw/BO_Nov2006_df.pkl')
BO_Feb2009 = pd.read_pickle('Obama Speeches Raw/BO_Feb2009_df.pkl')
BO_May2011 = pd.read_pickle('Obama Speeches Raw/BO_May2011_df.pkl')
BO_Aug2014 = pd.read_pickle('Obama Speeches Raw/BO_Aug2014_df.pkl')

# %%
BO_Nov2006.head()
# Out:
#                                             sentence
# 0  Throughout American history,               the...
# 1  They are the soul-trying times our forbearers ...
# 2  making the hard choices and sacrifices necessa...
# 3  This was true for those               who went...
# 4  It was true for those who lie               bu...

# %%
# add name of speech into each dataFrame
BO_Nov2006['speech'] = 'A way Forward in Iraq Nov2006'
BO_Feb2009['speech'] = 'Responsibly Ending the War in Iraq Feb2009'
BO_May2011['speech'] = 'American Diplomacy in Middle East and Northern Africa May2011'
BO_Aug2014['speech'] = 'Iraq Airstrikes and Humanitarian Aid Aug2014'

# %%
# reset indexes of each DataFrame 
BO_Nov2006.reset_index(inplace=True)
BO_Feb2009.reset_index(inplace=True)
BO_May2011.reset_index(inplace=True)
BO_Aug2014.reset_index(inplace=True)

# %% [markdown]
# ### Sentiment Analysis using RoBERTa Twitter model

# %%
# import modules
import transformers
from transformers import AutoTokenizer
from transformers import AutoModelForSequenceClassification
from scipy.special import softmax
from tqdm.notebook import tqdm # makes loops show a progress bar

# %%
# create tokenizer and model objects
MODEL = f"cardiffnlp/twitter-roberta-base-sentiment"
tokenizer = AutoTokenizer.from_pretrained(MODEL)
model = AutoModelForSequenceClassification.from_pretrained(MODEL)

# %%
def polarity_scores_roberta(speech_text):
# Create fucntion to apply model on a text and return scores
    encoded_text = tokenizer(speech_text, return_tensors='pt')
    output = model(**encoded_text)
    scores = output[0][0].detach().numpy()
    scores = softmax(scores) # returns a numpy array
    scores_dict = {
        "roberta_neg": scores[0],
        "roberta_neu": scores[1],
        "roberta_pos": scores[2],
    }
    return scores_dict

# %% [markdown]
# ##### Run the model on each dataFrame

# %%
from tqdm.notebook import tqdm_notebook

results = {}

# Set up tqdm_notebook with the total number of iterations
tqdm_bar = tqdm_notebook(total=len(BO_Nov2006))

for i, row in BO_Nov2006.iterrows():
    try:
        text = row['sentence']
        rowid = row['index'] # make sure DataFrame has reset index 
        results[rowid] = polarity_scores_roberta(text) # apply function and store in results dictionary

    except RuntimeError:
        print(f"Broke for id: {rowid}") # catch row id if bad response
        
    tqdm_bar.update(1)  # Update the progress bar

tqdm_bar.close()
# Out:
#   0%|          | 0/199 [00:00<?, ?it/s]

# %%
BO_Nov2006_results_df = pd.DataFrame(results).T
BO_Nov2006_df = pd.concat([BO_Nov2006, BO_Nov2006_results_df], axis=1)
BO_Nov2006_df
# Out:
#      index                                           sentence  \
# 0        0  Throughout American history,               the...
# 1        1  They are the soul-trying times our forbearers ...
# 2        2  making the hard choices and sacrifices necessa...
# 3        3  This was true for those               who went...
# 4        4  It was true for those who lie               bu...
# ..     ...                                                ...
# 194    194  The time for waiting in               Iraq is ...
# 195    195                   It is time to change our policy.
# 196    196  It is time to give               Iraqis their ...
# 197    197  And it is time to refocus America’s           ...
# 198    198                        Thank you.
#
#                             speech  roberta_neg  roberta_neu  roberta_pos
# 0    A way Forward in Iraq Nov2006     0.131547     0.740866     0.127587
# 1    A way Forward in Iraq Nov2006     0.173441     0.693343     0.133217
# 2    A way Forward in Iraq Nov2006     0.102811     0.694173     0.203016
# 3    A way Forward in Iraq Nov2006     0.026974     0.689914     0.283112
# 4    A way Forward in Iraq Nov2006     0.650926     0.319936     0.029138
# ..                             ...          ...          ...          ...
# 194  A way Forward in Iraq Nov2006     0.478585     0.482813     0.038602
# 195  A way Forward in Iraq Nov2006     0.202463     0.732728     0.064810
# 196  A way Forward in Iraq Nov2006     0.188637     0.648993     0.162370
# 197  A way Forward in Iraq Nov2006     0.178327     0.707893     0.113781
# 198  A way Forward in Iraq Nov2006     0.005306     0.217524     0.777170
#
# [199 rows x 6 columns]

# %%
results = {}

# Set up tqdm_notebook with the total number of iterations
tqdm_bar = tqdm_notebook(total=len(BO_Feb2009))

for i, row in BO_Feb2009.iterrows():
    try:
        text = row['sentence']
        rowid = row['index'] # make sure DataFrame has reset index 
        results[rowid] = polarity_scores_roberta(text) # apply function and store in results dictionary

    except RuntimeError:
        print(f"Broke for id: {rowid}") # catch row id if bad response
        
    tqdm_bar.update(1)  # Update the progress bar

tqdm_bar.close()
# Out:
#   0%|          | 0/177 [00:00<?, ?it/s]

# %%
BO_Feb2009_results_df = pd.DataFrame(results).T
BO_Feb2009_df = pd.concat([BO_Feb2009, BO_Feb2009_results_df], axis=1)
BO_Feb2009_df
# Out:
#      index                                           sentence  \
# 0        0                              Good morning Marines.
# 1        1                         Good morning Camp Lejeune.
# 2        2                         Good morning Jacksonville.
# 3        3            Thank you for that outstanding welcome.
# 4        4  I want to thank Lieutenant General Hejlik for ...
# ..     ...                                                ...
# 172    172  Your sacrifice should challenge all of us -- e...
# 173    173     There will be more danger in the months ahead.
# 174    174      We will face new tests and unforeseen trials.
# 175    175  But thanks to the sacrifices of those who have...
# 176    176  Thank you, God Bless you, and God Bless the Un...
#
#                                          speech  roberta_neg  roberta_neu  \
# 0    Responsibly Ending the War in Iraq Feb2009     0.005283     0.117133
# 1    Responsibly Ending the War in Iraq Feb2009     0.004063     0.277454
# 2    Responsibly Ending the War in Iraq Feb2009     0.007778     0.177322
# 3    Responsibly Ending the War in Iraq Feb2009     0.001327     0.008560
# 4    Responsibly Ending the War in Iraq Feb2009     0.002158     0.069132
# ..                                          ...          ...          ...
# 172  Responsibly Ending the War in Iraq Feb2009     0.285542     0.571485
# 173  Responsibly Ending the War in Iraq Feb2009     0.865656     0.128964
# 174  Responsibly Ending the War in Iraq Feb2009     0.208399     0.730318
# 175  Responsibly Ending the War in Iraq Feb2009     0.111227     0.497074
# 176  Responsibly Ending the War in Iraq Feb2009     0.001459     0.019849
#
#      roberta_pos
# 0       0.877583
# 1       0.718482
# 2       0.814900
# 3       0.990112
# 4       0.928709
# ..           ...
# 172     0.142972
# 173     0.005380
# 174     0.061283
# 175     0.391699
# 176     0.978692
#
# [177 rows x 6 columns]

# %%
results = {}

# Set up tqdm_notebook with the total number of iterations
tqdm_bar = tqdm_notebook(total=len(BO_May2011))

for i, row in BO_May2011.iterrows():
    try:
        text = row['sentence']
        rowid = row['index'] # make sure DataFrame has reset index 
        results[rowid] = polarity_scores_roberta(text) # apply function and store in results dictionary

    except RuntimeError:
        print(f"Broke for id: {rowid}") # catch row id if bad response
        
    tqdm_bar.update(1)  # Update the progress bar

tqdm_bar.close()
# Out:
#   0%|          | 0/271 [00:00<?, ?it/s]

# %%
BO_May2011_results_df = pd.DataFrame(results).T
BO_May2011_df = pd.concat([BO_May2011, BO_May2011_results_df], axis=1)
BO_May2011_df
# Out:
#      index                                           sentence  \
# 0        0                               Thank you very much.
# 1        1                                         Thank you.
# 2        2                               Please, have a seat.
# 3        3                               Thank you very much.
# 4        4  I want to begin by thanking Hillary Clinton, w...
# ..     ...                                                ...
# 266    266                            12 It will not be easy.
# 267    267  There’s no straight line to progress, and har ...
# 268    268  But the United States of America was founded o...
# 269    269  And now we cannot hesitate to stand squarely o...
# 270    270                    Thank you very much, everybody.
#
#                                                 speech  roberta_neg  \
# 0    American Diplomacy in Middle East and Northern...     0.002824
# 1    American Diplomacy in Middle East and Northern...     0.007133
# 2    American Diplomacy in Middle East and Northern...     0.244394
# 3    American Diplomacy in Middle East and Northern...     0.002824
# 4    American Diplomacy in Middle East and Northern...     0.001580
# ..                                                 ...          ...
# 266  American Diplomacy in Middle East and Northern...     0.477565
# 267  American Diplomacy in Middle East and Northern...     0.120123
# 268  American Diplomacy in Middle East and Northern...     0.160360
# 269  American Diplomacy in Middle East and Northern...     0.006380
# 270  American Diplomacy in Middle East and Northern...     0.001645
#
#      roberta_neu  roberta_pos
# 0       0.037212     0.959963
# 1       0.139902     0.852965
# 2       0.691612     0.063994
# 3       0.037212     0.959963
# 4       0.042995     0.955426
# ..           ...          ...
# 266     0.447358     0.075076
# 267     0.708587     0.171289
# 268     0.770617     0.069023
# 269     0.170502     0.823118
# 270     0.020804     0.977552
#
# [271 rows x 6 columns]

# %%
results = {}

# Set up tqdm_notebook with the total number of iterations
tqdm_bar = tqdm_notebook(total=len(BO_Aug2014))

for i, row in BO_Aug2014.iterrows():
    try:
        text = row['sentence']
        rowid = row['index'] # make sure DataFrame has reset index 
        results[rowid] = polarity_scores_roberta(text) # apply function and store in results dictionary

    except RuntimeError:
        print(f"Broke for id: {rowid}") # catch row id if bad response
        
    tqdm_bar.update(1)  # Update the progress bar

tqdm_bar.close()
# Out:
#   0%|          | 0/73 [00:00<?, ?it/s]

# %%
BO_Aug2014_results_df = pd.DataFrame(results).T
BO_Aug2014_df = pd.concat([BO_Aug2014, BO_Aug2014_results_df], axis=1)
BO_Aug2014_df
# Out:
#     index                                           sentence  \
# 0       0                                    Good evening.
# 1       1  Today I authorized two operations in  Iraq -- ...
# 2       2  Let me explain the actions we’re taking and wh...
# 3       3  First, I said in June -- as the terrorist grou...
# 4       4  In rece nt days, these terrorists have continu...
# ..    ...                                                ...
# 68     68                               That’s who we are.
# 69     69  So tonight, we give thanks to our men and wome...
# 70     70  They represent American leadership at its best.
# 71     71  As a nation, we should be proud of them,  and ...
# 72     72  God bless our Armed Forces, and God bless the ...
#
#                                           speech  roberta_neg  roberta_neu  \
# 0   Iraq Airstrikes and Humanitarian Aid Aug2014     0.003997     0.136151
# 1   Iraq Airstrikes and Humanitarian Aid Aug2014     0.406741     0.543621
# 2   Iraq Airstrikes and Humanitarian Aid Aug2014     0.104323     0.850220
# 3   Iraq Airstrikes and Humanitarian Aid Aug2014     0.265198     0.714070
# 4   Iraq Airstrikes and Humanitarian Aid Aug2014     0.755782     0.237042
# ..                                           ...          ...          ...
# 68  Iraq Airstrikes and Humanitarian Aid Aug2014     0.029198     0.486363
# 69  Iraq Airstrikes and Humanitarian Aid Aug2014     0.011584     0.106486
# 70  Iraq Airstrikes and Humanitarian Aid Aug2014     0.010095     0.197740
# 71  Iraq Airstrikes and Humanitarian Aid Aug2014     0.004900     0.079683
# 72  Iraq Airstrikes and Humanitarian Aid Aug2014     0.002530     0.055588
#
#     roberta_pos
# 0      0.859851
# 1      0.049638
# 2      0.045457
# 3      0.020732
# 4      0.007176
# ..          ...
# 68     0.484439
# 69     0.881929
# 70     0.792165
# 71     0.915417
# 72     0.941882
#
# [73 rows x 6 columns]

# %% [markdown]
# ##### Combine DataFrames

# %%
BO_combined_df = pd.concat([BO_Nov2006_df, BO_Feb2009_df, BO_May2011_df, BO_Aug2014_df], axis=0, ignore_index=True)
BO_combined_df.drop(columns=['index'], inplace=True)
BO_combined_df
# Out:
#                                               sentence  \
# 0    Throughout American history,               the...
# 1    They are the soul-trying times our forbearers ...
# 2    making the hard choices and sacrifices necessa...
# 3    This was true for those               who went...
# 4    It was true for those who lie               bu...
# ..                                                 ...
# 715                               That’s who we are.
# 716  So tonight, we give thanks to our men and wome...
# 717  They represent American leadership at its best.
# 718  As a nation, we should be proud of them,  and ...
# 719  God bless our Armed Forces, and God bless the ...
#
#                                            speech  roberta_neg  roberta_neu  \
# 0                   A way Forward in Iraq Nov2006     0.131547     0.740866
# 1                   A way Forward in Iraq Nov2006     0.173441     0.693343
# 2                   A way Forward in Iraq Nov2006     0.102811     0.694173
# 3                   A way Forward in Iraq Nov2006     0.026974     0.689914
# 4                   A way Forward in Iraq Nov2006     0.650926     0.319936
# ..                                            ...          ...          ...
# 715  Iraq Airstrikes and Humanitarian Aid Aug2014     0.029198     0.486363
# 716  Iraq Airstrikes and Humanitarian Aid Aug2014     0.011584     0.106486
# 717  Iraq Airstrikes and Humanitarian Aid Aug2014     0.010095     0.197740
# 718  Iraq Airstrikes and Humanitarian Aid Aug2014     0.004900     0.079683
# 719  Iraq Airstrikes and Humanitarian Aid Aug2014     0.002530     0.055588
#
#      roberta_pos
# 0       0.127587
# 1       0.133217
# 2       0.203016
# 3       0.283112
# 4       0.029138
# ..           ...
# 715     0.484439
# 716     0.881929
# 717     0.792165
# 718     0.915417
# 719     0.941882
#
# [720 rows x 5 columns]

# %% [markdown]
# ### Analyse the Results

# %% [markdown]
# We'll now assess the results of the model for each speech. The analysis will consist of the following:
# * top 5 most positive sentences
# * top 5 most negative sentences
# * average sentiment score

# %% [markdown]
# ##### Top 5 Analysis

# %%
df_sorted_pos
# Out:
#                                               sentence  \
# 719  God bless our Armed Forces, and God bless the ...
# 718  As a nation, we should be proud of them,  and ...
# 716  So tonight, we give thanks to our men and wome...
# 647                                    Good evening.
# 717  They represent American leadership at its best.
#
#                                            speech  roberta_neg  roberta_neu  \
# 719  Iraq Airstrikes and Humanitarian Aid Aug2014     0.002530     0.055588
# 718  Iraq Airstrikes and Humanitarian Aid Aug2014     0.004900     0.079683
# 716  Iraq Airstrikes and Humanitarian Aid Aug2014     0.011584     0.106486
# 647  Iraq Airstrikes and Humanitarian Aid Aug2014     0.003997     0.136151
# 717  Iraq Airstrikes and Humanitarian Aid Aug2014     0.010095     0.197740
#
#      roberta_pos
# 719     0.941882
# 718     0.915417
# 716     0.881929
# 647     0.859851
# 717     0.792165

# %%
for each in list(BO_combined_df['speech'].unique()):
    df = BO_combined_df[BO_combined_df['speech'] == each]
    df_sorted_pos = df.sort_values(by='roberta_pos', ascending=False).head(5)
    print(each)
    for i, row in df_sorted_pos.iterrows():
        print(f"{row['sentence']} | {row['roberta_pos']}")
    print('\n' '\n' '\n')
# Out:
# A way Forward in Iraq Nov2006
# Now, I am hopeful that               the Iraq Study Group emerges next month with a series of proposals               around which we can begin to build a bipartisan consensus. | 0.8604554533958435
# But we should know that our               success in doing so is enhanced by engaging our allies so that we               receive the crucial diplomatic, military, intelligence, and financial               support that can lighten our load and add legitimacy to our actions.                | 0.7828771471977234
# Thank you.                  | 0.7771697044372559
# Our best hope for success is to use the tools               we have ? | 0.7750783562660217
# I am               committed to working with this White House and any of my colleagues               in the months to come to craft such a consensus. | 0.7290148138999939
#
#
#
#
# Responsibly Ending the War in Iraq Feb2009
# Thank you for that outstanding welcome. | 0.9901123642921448
# Thank you, God Bless you, and God Bless the United States of America. | 0.9786924719810486
# He is an example of the very best that this nation has to offer, and we owe him a great debt of gratitude. | 0.9753099679946899
# We thank you and your families for all that you do for America. | 0.9694291353225708
# Thanks in great measure to your service, the situation in Iraq has improved. | 0.9467599987983704
#
#
#
#
# American Diplomacy in Middle East and Northern Africa May2011
# Thank you very much, everybody. | 0.9775517582893372
# Thank you very much. | 0.9599632620811462
# Thank you very much. | 0.9599632620811462
# I count on Hillary every single day, and I believe that she will go down as one of the finest Secretaries of State in our nation’s history.   | 0.9569978713989258
# I want to begin by thanking Hillary Clinton, who has traveled so much these last six months that she is approaching a new landmark -- one million frequent flyer miles. | 0.9554257988929749
#
#
#
#
# Iraq Airstrikes and Humanitarian Aid Aug2014
# God bless our Armed Forces, and God bless the Unite d States of America. | 0.941882312297821
# As a nation, we should be proud of them,  and of our country’s enduring commitment to uphold our own security and the dignity of our f ellow human beings.   | 0.9154168367385864
# So tonight, we give thanks to our men and women in uniform  -— especially our brave pilots and crews over Iraq who are protecting our fellow A mericans and saving the lives of so many men, women and children that they will never meet.   | 0.8819294571876526
# Good evening.   | 0.8598514199256897
# They represent American leadership at its best.   | 0.792165219783783

# %%
for each in list(BO_combined_df['speech'].unique()):
    df = BO_combined_df[BO_combined_df['speech'] == each]
    df_sorted_neg = df.sort_values(by='roberta_neg', ascending=False).head(5)
    print(each)
    for i, row in df_sorted_neg.iterrows():
        print(f"{row['sentence']} | {row['roberta_neg']}")
    print('\n' '\n' '\n')
# Out:
# A way Forward in Iraq Nov2006
# Today, the Iraqi landscape               is littered with ill-conceived, half-finished projects that have               done almost nothing to help the Iraqi people or stabilize the country. | 0.9608924984931946
# Such lack of foresight               is simply inexcusable. | 0.9567728042602539
# the American               people have determined that all these phrases have become meaningless               in the face of a conflict that grows more deadly and chaotic with               each passing day ? | 0.9480002522468567
# a conflict that has only increased the terrorist               threat it was supposed to help contain.2,867 Americans have now               died in this war. | 0.9474151730537415
# I refuse to accept the possibility that I will               have to come back a year from now and say the same thing. | 0.9457480311393738
#
#
#
#
# Responsibly Ending the War in Iraq Feb2009
# We cannot sustain indefinitely a commitment that has put a strain on our military, and will cost t he American people nearly a trillion dollars. | 0.9309462904930115
# You make up a fraction of the American population, but in an age when so many people and institutions have acted irresponsibly, yo u did the opposite -- you volunteered to bear the heaviest burden. | 0.9291971325874329
# Too many Iraqis are still displaced or destitute. | 0.9273005127906799
# Violence will continue to be a part of life in Iraq. | 0.9269793629646301
# They represen t the forces that destroy nations and lead only to despair, and they will test our will in the months and years to come. | 0.894149661064148
#
#
#
#
# American Diplomacy in Middle East and Northern Africa May2011
# For Israelis, it has meant living with the fear that their children could be blown up on a bus or by rockets fired at th eir homes, as well as the pain of knowing that other children in the region are taught to hate them. | 0.9611515998840332
# The most extreme example is Libya, where Muammar Qaddafi launched a war against his own people, promising to hunt them down like rats. | 0.953304648399353
# Given that this m istrust runs both ways -- as Americans have been seared by hostage -taking and violent rhetoric and terrorist attacks that have killed thousands of our citizens -- a failure to change our approach threatens a deepening spiral of division between the United States and the Arab world.   | 0.9498266577720642
# For Palestinians, it has meant suffering the humiliation of occupation, and never living in a nation of their own. | 0.9471604228019714
# It’s the same kind of humiliation that takes place every day in many parts of the world -- the rel entless tyranny of governments that deny their citizens dignity.  | 0.9451262354850769
#
#
#
#
# Iraq Airstrikes and Humanitarian Aid Aug2014
# So these innocent families are faced wit h a horrible choice:  descend the mountain and be slaughtered, or stay and slowly die of thirs t and hunger.   | 0.9578149914741516
# None of Iraq’s neighbo rs have an interest in this terrible suffering or instability.   | 0.9224737286567688
# People are starving.   | 0.9126502275466919
# Meanwhile, ISIL forces below have called for the systematic destruction of the e ntire Yezidi people, which would constitute genocide.   | 0.896837592124939
# And these terror ists have been especially barbaric towards religious minorities, including Christian and Yezid is, a small and ancient religious sect.   | 0.8944969773292542

# %% [markdown]
# It looks like the model has done a pretty good job of categorising the sentences into negative and positive. This top 5 analysis by sentiment type gives us confidence in the results.

# %% [markdown]
# ##### Average Sentiment Score
